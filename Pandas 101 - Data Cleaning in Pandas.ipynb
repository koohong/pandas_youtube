# %% [markdown]
# # Data Cleaning in Pandas

# %%
import pandas as pd

# %%
df = pd.read_excel("Customer Call List.xlsx")
print(df.head())

df[df.duplicated(keep=False)]
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True
#     CustomerID First_Name  Last_Name  Phone_Number  \
# ...

# %%
df[df.duplicated()]
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                         Address Paying Customer Do_Not_Contact  \
# 20  910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 20               True

# %%
df[df["Last_Name"] == "Skywalker"]
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 19        1020     Anakin  Skywalker  876|678|3469
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                         Address Paying Customer Do_Not_Contact  \
# 19  910 Tatooine Road, Tatooine             Yes              N
# 20  910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 19               True
# 20               True

# %%
df = df.drop_duplicates()

# %%
df.groupby("Do_Not_Contact")["CustomerID"].count()
# Out:
# Do_Not_Contact
# N      3
# No     9
# Y      1
# Yes    3
# Name: CustomerID, dtype: int64

# %%
df.shape
# Out:
# (20, 8)

# %%
df = df.drop_duplicates()
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
#0,1,2,3,4,5.   only include 3 and 4.  5 is excluded
df.iloc[:,3:5].head()
# Out:
#    Phone_Number                                Address
# 0  123-545-5421                  123 Shire Lane, Shire
# 1  123/643/9775                    93 West Main Street
# 2    7066950392                     298 Drugs Driveway
# 3  123-543-2345  980 Paper Avenue, Pennsylvania, 18503
# 4  876|678|3469                       123 Dragons Road

# %%
df.drop(columns = ["Not_Useful_Column", "Phone_Number"]).head()
# Out:
#    CustomerID First_Name Last_Name                                Address  \
# 0        1001      Frodo   Baggins                  123 Shire Lane, Shire
# 1        1002       Abed     Nadir                    93 West Main Street
# 2        1003     Walter    /White                     298 Drugs Driveway
# 3        1004     Dwight   Schrute  980 Paper Avenue, Pennsylvania, 18503
# 4        1005        Jon      Snow                       123 Dragons Road
#
#   Paying Customer Do_Not_Contact
# 0             Yes             No
# 1              No            Yes
# 2               N            NaN
# 3             Yes              Y
# 4               Y             No

# %%
df.iloc[:,df.columns.str.contains("n")].head()
# Out:
#    Phone_Number Paying Customer Do_Not_Contact  Not_Useful_Column
# 0  123-545-5421             Yes             No               True
# 1  123/643/9775              No            Yes              False
# 2    7066950392               N            NaN               True
# 3  123-543-2345             Yes              Y               True
# 4  876|678|3469               Y             No               True

# %%
df.loc[:, df.columns.str.contains("n")].head()
# Out:
#    Phone_Number Paying Customer Do_Not_Contact  Not_Useful_Column
# 0  123-545-5421             Yes             No               True
# 1  123/643/9775              No            Yes              False
# 2    7066950392               N            NaN               True
# 3  123-543-2345             Yes              Y               True
# 4  876|678|3469               Y             No               True

# %%
df.loc[:, df.columns.str.contains(r"[nL]")].head()
# Out:
#   Last_Name  Phone_Number Paying Customer Do_Not_Contact  Not_Useful_Column
# 0   Baggins  123-545-5421             Yes             No               True
# 1     Nadir  123/643/9775              No            Yes              False
# 2    /White    7066950392               N            NaN               True
# 3   Schrute  123-543-2345             Yes              Y               True
# 4      Snow  876|678|3469               Y             No               True

# %%
df["Last_Name"].str.lstrip(".../").head(21)
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: str

# %%
#df["Last_Name"] = 
#df["Last_Name"] = df["Last_Name"].str.lstrip("/")
#df["Last_Name"] = df["Last_Name"].str.rstrip("_")
df["Last_Name"] = df["Last_Name"].str.strip("123._/")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
#df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')

#df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])

#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))

#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])

df["Phone_Number"] = df["Phone_Number"].str.replace('nan--','')

df["Phone_Number"] = df["Phone_Number"].str.replace('Na--','')
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter     White           NaN
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
df["Phone_Number"].fillna('')
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10
# 11
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17
# 18             N/a
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %%
#2 is the maximum number of splits per string 
df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',', n=2, expand=True)
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter     White           NaN
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column       Street_Address          State Zip_Code
# 0               True       123 Shire Lane          Shire      NaN
# 1              False  93 West Main Street            NaN      NaN
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes','Y')
df["Do_Not_Contact"] = df["Do_Not_Contact"].fillna('')
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No','N')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White           NaN
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter           NaN
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
#df = df.replace('N/a','')
#df = df.replace('NaN','')

df=df.fillna('')
df["Phone_Number"] = df["Phone_Number"].str.replace('N/a','')
df["Phone_Number"] = df["Phone_Number"].str.replace('NaN','')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
#if you simply assign them, they will remain linked
df2 = df.copy()

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
df.loc[df.index.values,:]
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %% [markdown]
# `inplace = True` : makes the changes to df in memeory and do not return a new df

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"] == 'Y':
        df.drop(x, inplace=True)

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White
# 4         1005        Jon        Snow  876|678|3469
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 17        1018      Clark        Kent
# 19        1020     Anakin   Skywalker  876|678|3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire             Yes              N
# ...

# %%
for x in df.index:
    if df.loc[x, "Phone_Number"] == '':
        df.drop(x, inplace=True)
df

#Another way to drop null values
#df = df.dropna(subset="Phone_Number"), inplace=True)
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 4         1005        Jon        Snow  876|678|3469
# 7         1008   Sherlock      Holmes  876|678|3469
# 9         1010      Peter      Parker  123-545-5421
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 19        1020     Anakin   Skywalker  876|678|3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire             Yes              N
# 4                 123 Dragons Road               Y              N
# 7                    98 Clue Drive               N              N
# 9       25th Main Street, New York             Yes              N
# ...

# %%
df2.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter     White
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes              N
# 1                    93 West Main Street              No              Y
# 2                     298 Drugs Driveway               N
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y              N
#
#    Not_Useful_Column       Street_Address          State Zip_Code
# 0               True       123 Shire Lane          Shire
# 1              False  93 West Main Street
# 2               True   298 Drugs Driveway
# ...

# %%
df2.loc[(df2["Do_Not_Contact"]=="Y")  & (df2["Last_Name"] == "Nadir"),:]
# Out:
#    CustomerID First_Name Last_Name  Phone_Number              Address  \
# 1        1002       Abed     Nadir  123/643/9775  93 West Main Street
#
#   Paying Customer Do_Not_Contact  Not_Useful_Column       Street_Address  \
# 1              No              Y              False  93 West Main Street
#
#   State Zip_Code
# 1

# %%
df3 = df2[df2["Do_Not_Contact"].isin(["Y","N"])]
df3
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876|678|3469
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# ...

# %%
# after you filter you need to reset the index
df3 = df3.reset_index(drop=True)
df3
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1004     Dwight     Schrute  123-543-2345
# 3         1005        Jon        Snow  876|678|3469
# 4         1006        Ron     Swanson  304-762-2467
# 5         1007       Jeff      Winger
# 6         1008   Sherlock      Holmes  876|678|3469
# 7         1010      Peter      Parker  123-545-5421
# 8         1011    Samwise      Gamgee
# 9         1013        Don      Draper  123-543-2345
# 10        1014     Leslie       Knope  876|678|3469
# 11        1015       Toby  Flenderson  304-762-2467
# 12        1016        Ron     Weasley  123-545-5421
# 13        1017   Michael        Scott  123/643/9775
# 14        1019      Creed      Braton
# 15        1020     Anakin   Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# ...
